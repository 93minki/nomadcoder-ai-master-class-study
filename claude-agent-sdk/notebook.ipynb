# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from claude_agent_sdk import (
    AssistantMessage,
    ResultMessage,
    SystemMessage,
    TextBlock,
    query,
)

async for message in query(prompt="What was the capital of Westphalia"):
    if isinstance(message, SystemMessage):
        print("SystemMessage")
    elif isinstance(message, AssistantMessage):
        for block in message.content:
            if isinstance(block, TextBlock):
                print(f"AssistantMessage = {block.text}")
    elif isinstance(message, ResultMessage):
        print(f"ResultMessage ${message.total_cost_usd}")
# Out:
# HookEventMessage(subtype='hook_started', data={'type': 'system', 'subtype': 'hook_started', 'hook_id': '5dbfa8d0-763b-413a-bb09-7b74c4166e4c', 'hook_name': 'SessionStart:startup', 'hook_event': 'SessionStart', 'uuid': '583b9592-d75a-4bac-b60a-b8815a886833', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8'}, hook_event_name='SessionStart', session_id='55ffb0ca-6794-4022-947c-580548f2d3e8', uuid='583b9592-d75a-4bac-b60a-b8815a886833')
#
#
# HookEventMessage(subtype='hook_response', data={'type': 'system', 'subtype': 'hook_response', 'hook_id': '5dbfa8d0-763b-413a-bb09-7b74c4166e4c', 'hook_name': 'SessionStart:startup', 'hook_event': 'SessionStart', 'output': 'CAVEMAN MODE ACTIVE — level: full\n\nRespond terse like smart caveman. All technical substance stay. Only fluff die.\n\n## Persistence\n\nACTIVE EVERY RESPONSE. No revert after many turns. No filler drift. Still active if unsure. Off only: "stop caveman" / "normal mode".\n\nCurrent level: **full**. Switch: `/caveman lite|full|ultra`.\n\n## Rules\n\nDrop: articles (a/an/the), filler (just/really/basically/actually/simply), pleasantries (sure/certainly/of course/happy to), hedging. Fragments OK. Short synonyms (big not extensive, fix not "implement a solution for"). Technical terms exact. Code blocks unchanged. Errors quoted exact.\n\nPattern: `[thing] [action] [reason]. [next step].`\n\nNot: "Sure! I\'d be happy to help you with that. The issue you\'re experiencing is likely caused by..."\nYes: "Bug in auth middleware. Token expiry check use `<` not `<=`. Fix:"\n\n## Auto-Clarity\n\nDrop caveman for: security warnings, irreversible action confirmations, multi-step sequences where fragment order risks misread, user asks to clarify or repeats question. Resume caveman after clear part done.\n\n## Boundaries\n\nCode/commits/PRs: write normal. "stop caveman" or "normal mode": revert. Level persist until changed or session end.\n\nSTATUSLINE SETUP NEEDED: The caveman plugin includes a statusline badge showing active mode (e.g. [CAVEMAN], [CAVEMAN:ULTRA]). It is not configured yet. To enable, add this to /Users/93minki/.claude/settings.json: "statusLine": { "type": "command", "command": "bash \\"/Users/93minki/.claude/plugins/cache/caveman/caveman/25d22f864ad6/src/hooks/caveman-statusline.sh\\"" } Proactively offer to set this up for the user on first interaction.', 'stdout': 'CAVEMAN MODE ACTIVE — level: full\n\nRespond terse like smart caveman. All technical substance stay. Only fluff die.\n\n## Persistence\n\nACTIVE EVERY RESPONSE. No revert after many turns. No filler drift. Still active if unsure. Off only: "stop caveman" / "normal mode".\n\nCurrent level: **full**. Switch: `/caveman lite|full|ultra`.\n\n## Rules\n\nDrop: articles (a/an/the), filler (just/really/basically/actually/simply), pleasantries (sure/certainly/of course/happy to), hedging. Fragments OK. Short synonyms (big not extensive, fix not "implement a solution for"). Technical terms exact. Code blocks unchanged. Errors quoted exact.\n\nPattern: `[thing] [action] [reason]. [next step].`\n\nNot: "Sure! I\'d be happy to help you with that. The issue you\'re experiencing is likely caused by..."\nYes: "Bug in auth middleware. Token expiry check use `<` not `<=`. Fix:"\n\n## Auto-Clarity\n\nDrop caveman for: security warnings, irreversible action confirmations, multi-step sequences where fragment order risks misread, user asks to clarify or repeats question. Resume caveman after clear part done.\n\n## Boundaries\n\nCode/commits/PRs: write normal. "stop caveman" or "normal mode": revert. Level persist until changed or session end.\n\nSTATUSLINE SETUP NEEDED: The caveman plugin includes a statusline badge showing active mode (e.g. [CAVEMAN], [CAVEMAN:ULTRA]). It is not configured yet. To enable, add this to /Users/93minki/.claude/settings.json: "statusLine": { "type": "command", "command": "bash \\"/Users/93minki/.claude/plugins/cache/caveman/caveman/25d22f864ad6/src/hooks/caveman-statusline.sh\\"" } Proactively offer to set this up for the user on first interaction.', 'stderr': '', 'exit_code': 0, 'outcome': 'success', 'uuid': '25f0604d-ee8f-4dbf-bf5d-c4aa2c7dbbff', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8'}, hook_event_name='SessionStart', session_id='55ffb0ca-6794-4022-947c-580548f2d3e8', uuid='25f0604d-ee8f-4dbf-bf5d-c4aa2c7dbbff')
#
#
# SystemMessage(subtype='init', data={'type': 'system', 'subtype': 'init', 'cwd': '/Users/93minki/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'tools': ['Task', 'Bash', 'CronCreate', 'CronDelete', 'CronList', 'DesignSync', 'Edit', 'EnterWorktree', 'ExitWorktree', 'ListAgents', 'Monitor', 'NotebookEdit', 'PushNotification', 'Read', 'ReportFindings', 'ScheduleWakeup', 'SendMessage', 'Skill', 'TaskOutput', 'TaskStop', 'ToolSearch', 'WebFetch', 'WebSearch', 'Workflow', 'Write'], 'mcp_servers': [], 'model': 'claude-opus-5[1m]', 'permissionMode': 'default', 'slash_commands': ['enhance-harness', 'harness-builder', 'math-curriculum-checker', 'math-type-converter', 'deep-research', 'pumasi:image', 'pumasi:pumasi', 'pumasi:pumasi-image', 'caveman:cavecrew', 'caveman:caveman', 'caveman:caveman-commit', 'caveman:caveman-compress', 'caveman:caveman-help', 'caveman:caveman-review', 'caveman:caveman-stats', 'design-sync', 'dataviz', 'update-config', 'verify', 'debug', 'code-review', 'simplify', 'batch', 'fewer-permission-prompts', 'doctor', 'loop', 'claude-api', 'run', 'run-skill-generator', 'agents', 'auto-mode-setup', 'autocompact', 'clear', 'color', 'compact', 'config', 'context', 'effort', 'fast', 'init', 'mcp', 'import', 'model', '__remote-workflow', 'workflow-launch-exec', 'reload-skills', 'rename', 'security-review', 'usage', 'insights', 'recap', 'goal', 'design', 'design-consent', 'design-revoke', 'list-agents', 'team-onboarding'], 'terminal_slash_commands': ['doctor', 'color'], 'apiKeySource': 'ANTHROPIC_API_KEY', 'claude_code_version': '2.1.239', 'output_style': 'default', 'agents': ['caveman:cavecrew-builder', 'caveman:cavecrew-investigator', 'caveman:cavecrew-reviewer', 'claude', 'Explore', 'general-purpose', 'Plan', 'statusline-setup'], 'skills': ['enhance-harness', 'harness-builder', 'math-curriculum-checker', 'math-type-converter', 'deep-research', 'pumasi:pumasi', 'pumasi:pumasi-image', 'caveman:cavecrew', 'caveman:caveman', 'caveman:caveman-commit', 'caveman:caveman-compress', 'caveman:caveman-help', 'caveman:caveman-review', 'caveman:caveman-stats', 'design-sync', 'dataviz', 'update-config', 'verify', 'debug', 'code-review', 'simplify', 'batch', 'fewer-permission-prompts', 'doctor', 'loop', 'claude-api', 'run', 'run-skill-generator'], 'plugins': [{'name': 'pumasi', 'path': '/Users/93minki/.claude/plugins/cache/gptaku-plugins/pumasi/1.8.1', 'source': 'pumasi@gptaku-plugins', 'version': '1.8.1'}, {'name': 'caveman', 'path': '/Users/93minki/.claude/plugins/cache/caveman/caveman/25d22f864ad6', 'source': 'caveman@caveman'}], 'capabilities': ['interrupt_receipt_v1', 'interrupt_cancel_queued_v1', 'msg_lifecycle_v1'], 'analytics_disabled': False, 'product_feedback_disabled': True, 'uuid': 'e53b88fb-854a-46ea-aa78-ec508806b841', 'memory_paths': {'auto': '/Users/93minki/.claude/projects/-Users-93minki-Desktop-Study-nomadcoder-ai-master-class-study/memory/'}, 'messaging_socket_path': '/tmp/cc-socks/48941.sock', 'fast_mode_state': 'off', 'fast_mode_disabled_reason': 'sdk_opt_in_required'})
#
#
# SystemMessage(subtype='api_retry', data={'type': 'system', 'subtype': 'api_retry', 'attempt': 1, 'max_retries': 10, 'retry_delay_ms': 576, 'error_status': 401, 'error': 'authentication_failed', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'uuid': 'f3f26c84-b737-4eee-90fa-51be9bcf0c19'})
#
#
# SystemMessage(subtype='api_retry', data={'type': 'system', 'subtype': 'api_retry', 'attempt': 2, 'max_retries': 10, 'retry_delay_ms': 1192, 'error_status': 401, 'error': 'authentication_failed', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'uuid': 'cdaa1b9a-ed10-43bd-b03b-49947425fb74'})
#
#
# SystemMessage(subtype='api_retry', data={'type': 'system', 'subtype': 'api_retry', 'attempt': 3, 'max_retries': 10, 'retry_delay_ms': 2027, 'error_status': 401, 'error': 'authentication_failed', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'uuid': 'd60ad61b-ffed-44a9-8c0e-07c18130c50c'})
#
#
# SystemMessage(subtype='api_retry', data={'type': 'system', 'subtype': 'api_retry', 'attempt': 4, 'max_retries': 10, 'retry_delay_ms': 4310, 'error_status': 401, 'error': 'authentication_failed', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'uuid': '496b21d5-e854-4749-902c-27c4abe258db'})
#
#
# SystemMessage(subtype='api_retry', data={'type': 'system', 'subtype': 'api_retry', 'attempt': 5, 'max_retries': 10, 'retry_delay_ms': 9059, 'error_status': 401, 'error': 'authentication_failed', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'uuid': '9955a43b-6379-471b-9229-67ccdbdc5658'})
#
#
# SystemMessage(subtype='api_retry', data={'type': 'system', 'subtype': 'api_retry', 'attempt': 6, 'max_retries': 10, 'retry_delay_ms': 16525, 'error_status': 401, 'error': 'authentication_failed', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'uuid': '1fd181a9-082e-47d9-bfd2-d7db4828fd98'})
#
#
# SystemMessage(subtype='api_retry', data={'type': 'system', 'subtype': 'api_retry', 'attempt': 7, 'max_retries': 10, 'retry_delay_ms': 32760, 'error_status': 401, 'error': 'authentication_failed', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'uuid': 'e640cc3f-8c70-4a44-9397-1a2382b776c1'})
#
#
# SystemMessage(subtype='api_retry', data={'type': 'system', 'subtype': 'api_retry', 'attempt': 8, 'max_retries': 10, 'retry_delay_ms': 35281, 'error_status': 401, 'error': 'authentication_failed', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'uuid': '0e176543-dc79-487f-a1eb-a316b285ee0d'})
#
#
# SystemMessage(subtype='api_retry', data={'type': 'system', 'subtype': 'api_retry', 'attempt': 9, 'max_retries': 10, 'retry_delay_ms': 33941, 'error_status': 401, 'error': 'authentication_failed', 'session_id': '55ffb0ca-6794-4022-947c-580548f2d3e8', 'uuid': 'a84e97d8-d182-45a4-8300-a17ca93c5f86'})
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# File ~/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk/.venv/lib/python3.14/site-packages/anyio/streams/memory.py:118, in MemoryObjectReceiveStream.receive(self)
#     117 try:
# --> 118     return self.receive_nowait()
#     119 except WouldBlock:
#     120     # Add ourselves in the queue
#
# File ~/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk/.venv/lib/python3.14/site-packages/anyio/streams/memory.py:113, in MemoryObjectReceiveStream.receive_nowait(self)
#     111     raise EndOfStream
# --> 113 raise WouldBlock
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 from claude_agent_sdk import query
#       2
# ----> 3 async for message in query(prompt="hello"):
#       4     print(message, "\n\n")
#       5
#
# File ~/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk/.venv/lib/python3.14/site-packages/claude_agent_sdk/query.py:123, in query(prompt, options, transport)
#     119     options = ClaudeAgentOptions()
#     121 client = InternalClient()
# --> 123 async for message in client.process_query(
#     124     prompt=prompt, options=options, transport=transport
#     125 ):
#     126     yield message
#
# File ~/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk/.venv/lib/python3.14/site-packages/claude_agent_sdk/_internal/client.py:56, in InternalClient.process_query(self, prompt, options, transport)
#      54 inner = self._process_query_inner(prompt, options, transport, materialized)
#      55 try:
# ---> 56     async for msg in inner:
#      57         yield msg
#      58 finally:
#      59     # ``async for`` does NOT close its iterator when the loop body
#      60     # raises (PEP 533 was deferred). Explicitly aclose the inner
#      61     # generator first so its ``finally: await query.close()`` runs —
#      62     # i.e. the subprocess is terminated — *before* we remove the temp
#      63     # CLAUDE_CONFIG_DIR it is reading/writing.
#
# File ~/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk/.venv/lib/python3.14/site-packages/claude_agent_sdk/_internal/client.py:189, in InternalClient._process_query_inner(self, prompt, options, transport, materialized)
#     186     query.spawn_task(query.stream_input(prompt))
#     188 # Yield parsed messages, skipping unknown message types
# --> 189 async for data in query.receive_messages():
#     190     message = parse_message(data)
#     191     if message is not None:
#
# File ~/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk/.venv/lib/python3.14/site-packages/claude_agent_sdk/_internal/query.py:896, in Query.receive_messages(self)
#     894 async def receive_messages(self) -> AsyncIterator[dict[str, Any]]:
#     895     """Receive SDK messages (not control messages)."""
# --> 896     async for message in self._message_receive:
#     897         # Check for special messages
#     898         if message.get("type") == "end":
#     899             break
#
# File ~/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk/.venv/lib/python3.14/site-packages/anyio/abc/_streams.py:35, in UnreliableObjectReceiveStream.__anext__(self)
#      33 async def __anext__(self) -> T_co:
#      34     try:
# ---> 35         return await self.receive()
#      36     except EndOfStream:
#      37         raise StopAsyncIteration from None
#
# File ~/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk/.venv/lib/python3.14/site-packages/anyio/streams/memory.py:126, in MemoryObjectReceiveStream.receive(self)
#     123 self._state.waiting_receivers[receive_event] = receiver
#     125 try:
# --> 126     await receive_event.wait()
#     127 finally:
#     128     self._state.waiting_receivers.pop(receive_event, None)
#
# File ~/Desktop/Study/nomadcoder-ai-master-class-study/claude-agent-sdk/.venv/lib/python3.14/site-packages/anyio/_backends/_asyncio.py:1866, in Event.wait(self)
#    1864     await AsyncIOBackend.checkpoint()
#    1865 else:
# -> 1866     await self._event.wait()
#
# File ~/.local/share/uv/python/cpython-3.14.7-macos-aarch64-none/lib/python3.14/asyncio/locks.py:213, in Event.wait(self)
#     211 self._waiters.append(fut)
#     212 try:
# --> 213     await fut
#     214     return True
#     215 finally:
#
# CancelledError:
